# %% [markdown]
# <table style="width:100%; border:0;">
#   <tr>
#     <td style="text-align:left; border:0;">
#       <h1 style="margin:0;">MÓDULO 2: GESTIÓN DE CARTERAS</h1>
#     </td>
#     <td style="text-align:right; border:0;">
#       <img src="https://drive.google.com/uc?export=view&id=169adrsNVSW-MwT9xytWV52tNxKpuuBgq"
#            width="160"
#            alt="LogoBME">
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ### Profesores
#
# - [Alfonso Santos](https://www.uam.es/Economicas/santos-ramon-alfonso/1242667903456.htm?language=es&pid=1242653687745&title=Santos%20Ram?n%20Alfonso).
#
#     - Master de IA aplicado a los Mercados Financieros del Instituto  BME.
#
#     - Grado Economía y Finanzas Universidad Autónoma de Madrid.
#
#     - Ingeniero Superior de Telecomunicaciones Universidad Politécnica de Madrid.
#
#     - Profesor Asociado Dpto Financiación e Investigación Comercial. Facultad Económicas y Empresariales Universidad Autónoma de Madrid.
#
# - [Fernando Úbeda](https://www.uam.es/Economicas/%C3%9Abeda-Mellina,-Fernando/1234888497623.htm?language=es&pid=1234888496695&title=?beda%20Mellina,%20Fernando).
#
#     - Doctor en Economía y Empresa. Universidad Autónoma de Madrid.
#
#     - Profesor Titular Dpto Financiación e Investigación Comercial. Facultad Económicas y Empresariales. Universidad Autónoma de Madrid.

# %% [markdown]
# Los **objetivos específicos** del módulo son:
#
# * Fundamentos Teóricos: Profundizar en la teoría moderna de carteras, comprendiendo conceptos esenciales que rigen la gestión de inversiones.
#
# * Aplicación Práctica con Python: Utilizar Python para simular, optimizar y validar estrategias de inversión basadas en los conceptos teóricos aprendidos.

# %% [markdown]
# El curso está basado en los libros:
#
# <img src="https://github.com/alfonso-santos/microcredencial-carteras-python/blob/Feb-2025/imgs/libros_recomendados.jpg?raw=1" alt="Libros recomendados" style="max-width:100%">

# %% [markdown]
# ## Contenido del curso

# %% [markdown]
# #### TEMA 1: Introducción carteras
#
# * **1.1** [ Carteras de dos activos](https://colab.research.google.com/drive/1dOGZWo2OocnZXDt3tqzXCRSL-JCZ9ktn)
#
# * **1.2** [Carteras de cuatro activos](https://colab.research.google.com/drive/1tnfK2Jm3ZDp3OCX5qLkZBeqD4JS85aX0)
#
# * **1.3** [Análisis del efecto de la diversificación](https://colab.research.google.com/drive/1XdfEZhLaTqp16tdiW1q7CrL47vfmH57j)
#
# * **Apéndice** [Fórmulas carteras](https://colab.research.google.com/drive/1axU9QNKS-qodTsmqeEPwGL2W1DZc4Rhc)

# %% [markdown]
# ### Tema 2: Fundamentos de Gestión de Carteras y Riesgo: Markowitz y Tobin

# %% [markdown]
# * **2.1** [ Introducción a la
# optimización media-varianza](https://colab.research.google.com/drive/1EuVbYZ1v6X4B1m2TvMx_nBTPjm9haoVf)
#
#
# * **2.2** [Conceptos iniciales de optimización](https://colab.research.google.com/drive/1YkF6zN6Nk4T9wWK1mGuYwDWoNTQmHimc)
#
#
# * **2.3** [Introducción a la librería CVXPY](https://colab.research.google.com/drive/1LLm5WCIn9Q8Uad2TF57hGASEodgrk-dQ)
#
#
# * **2.4** [Optimización de carteras (Markowitz)](https://colab.research.google.com/drive/1XupqczaCk9NClKFNy4sQsNQPdC0mreen)
#
#
# * **2.5** [Optimización de carteras con posiciones cortas (Markowitz)](https://colab.research.google.com/drive/1H07_kRDfz59fpdAp1P06IveviiWTa0Xz)
#
# * **2.6** [ Introducción del activo libre de riesgo: Teoría de Tobin](https://colab.research.google.com/drive/1v6WpmxT5FnIPhAuRxSABWbrTM-ksRo9T)
#
#
# [Apéndice](Tema_3_Markowitz/src/ejemplos-riskfolio.ipynb) Ejemplos avanzados de optimización usando la librería Riskfolio

# %% [markdown]
# ### TEMA 3: Modelos de Riesgo Sistemático y Valoración de Activos: CAPM y Modelo de mercado

# %% [markdown]
# * **3.2** [ CAPM ](https://colab.research.google.com/drive/1TuwlNrRxRNfC-G8oTXQO0nquDBompe0q)
#
# * **3.3** [ Modelo de mercado ](https://colab.research.google.com/drive/1MrztwJLMOfbDCq8fkSZB_Pp6QQq_DYg3)
#
# * **3.4** [ Comprobación modelo mercado con activos del SP500 ](https://colab.research.google.com/drive/1S5l51KCa-gwD5AmpQsDaifgd0A71lv5Y)

# %% [markdown]
# #### TEMA 4: SMART BETAS
#
# * **4.1** [ Análisis de los factores de Fama-French ](https://colab.research.google.com/drive/13g1dfdwRVP4XvFA_3CNnmZSs5koyqImV)
#
# * **4.2** [ Análisis de fondos de inversión ](https://colab.research.google.com/drive/1ak8VGJF_NwbuhPk__GEKWDwZSyHPbaZd)
#
# * **4.3** [ Diseño de caretras con factores ](https://colab.research.google.com/drive/1OqhIdBm4uw5BVOmpsLNB7cBfUtFbhNLY)

# %% [markdown]
# ____

# %% [markdown]
# # **Notebooks con los ejercicios resueltos**
